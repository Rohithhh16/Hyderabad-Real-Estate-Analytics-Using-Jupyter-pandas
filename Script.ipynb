# %%
#  importing all modules

import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Creating a web scrapping bot code

# %%
price = []
sqft = []
price_sqft = []
type_bhk = []
agent = []
area = []
date_of_posted = []
direction = []
parkings = []
for i in range(1,1000):
    url= f"https://www.commonfloor.com/hyderabad-property/for-sale?page={i}"
    response = requests.get(url)
    page = BeautifulSoup(response.text)
    for i in page.find_all("span",class_="s_p"):
        if re.findall(".",i.text):
            price.append("".join(re.findall(".",i.text)))
        else: 
            price.append(np.nan)

    for i in page.find_all("a",class_="snblink clearfix"):
        if re.findall("(\d.+)\(",i.text):
            sqft.append("".join(re.findall("(\d.+)\(",i.text)))
        else:
            sqft.append(np.nan)

    for i in page.find_all("a",class_="snblink clearfix"):
        if re.findall("\@(\s\d.+)\/",i.text):
            price_sqft.append("".join(re.findall("\@(\s\d.+)\/",i.text)))
        else:
            price_sqft.append(np.nan)

    for i in page.find_all("div",class_="infownertext"):
        if re.findall("Agent.+\n(\w.+)",i.text):
            agent.append("".join(re.findall("Agent.+\n(\w.+)",i.text)))
        else:
            agent.append(np.nan)

    for i in page.find_all("div",class_="posteddate"):
        if re.findall("\:\s(\d+)",i.text):
            date_of_posted.append("".join(re.findall("\:\s(\d+)",i.text)))
        else:
            date_of_posted.append(np.nan)

    for i in page.find_all("div",class_="st_title"):
        if re.findall("\d+\s*BHK\s[A-Za-z]+",i.text):
            type_bhk.append("".join(re.findall("\d+\s*BHK\s[A-Za-z]+",i.text)))
        else:
            type_bhk.append(np.nan)

    for i in page.find_all("div",class_="st_title"):
        if re.findall("in\s(\w.+)",i.text):
            area.append("".join(re.findall("in\s(\w.+)",i.text)))
        else:
            area.append(np.nan)
    for i in page.find_all("div",class_="st_title"):
        if re.findall(".",i.text):
            direction.append("".join(re.findall(".",i.text)))
        else:
            direction.append(np.nan)
    for i in page.find_all("div",class_="st_title"):
        if re.findall(".",i.text):
            parkings.append("".join(re.findall(".",i.text)))
        else:
            parkings.append(np.nan)

# %%
# comaparing the lengths of the attributes which scraped from the common floor website

# %%
print(len(price),len(price_sqft),len(sqft),len(area),len(type_bhk),len(agent),len(date_of_posted))
# Out:
# 23970 23970 23970 23970 23970 23970 23970

# %%
# Creating Dataframe with these attributes

# %%
df = pd.DataFrame({"a":sqft,"b":price,"c":price_sqft,"d":area,"q":type_bhk,"t":date_of_posted,"x":agent,"y":direction,"z":parkings})

# %%
# saving that dataset to local direcory or files for further usage

# %%
df.to_csv("project_data_long.csv")

# %%
# reading the csv file which we are saved above

# %%
df = pd.read_csv("project_data_Long.csv")

# %%
df
# Out:
#        Unnamed: 0            a                  b      c  \
# 0               0  1800 sq.ft       64 L            3556
# 1               1  1300 sq.ft    70.20 L            5400
# 2               2  1108 sq.ft    43.67 L            3942
# 3               3  1742 sq.ft    1.27 Cr            7308
# 4               4   814 sq.ft       31 L            3808
# ...           ...          ...                ...    ...
# 23965       23965   864 sq.ft    46.65 L            5400
# 23966       23966  1226 sq.ft    1.07 Cr            8793
# 23967       23967  1520 sq.ft    1.25 Cr            8250
# 23968       23968  1154 sq.ft    82.48 L            7148
# 23969       23969  1600 sq.ft    1.76 Cr           11000
#
#                                                  d                q     t  \
# 0                        Srisailam Highway                      NaN   3.0
# 1                Gayatri Nagar-Saroornagar           3BHK Apartment  20.0
# 2      Ganesh Nagar Colony-Vanasthalipuram           2BHK Apartment  20.0
# 3              Sri Guru Raghavendra Colony           3BHK Apartment  27.0
# 4                               Beeramguda          2 BHK Apartment  25.0
# ...                                            ...              ...   ...
# 23965                           Rani Vihar          2 BHK Apartment  17.0
# 23966          Sharada Nagar-Dilsukh Nagar          3 BHK Apartment  17.0
# 23967                          Vimana Puri          3 BHK Apartment  17.0
# 23968                           Yakhutpura          2 BHK Apartment  17.0
# 23969                     North Kalyanpuri          3 BHK Apartment  17.0
#
#                    x     y        z
# 0             venkat  east  UnKnown
# 1               Arun  east       No
# 2       Lorgannaresh  east      Yes
# 3        Deepika Rao  east      Yes
# 4          Bijoy Rao  east      Yes
# ...              ...   ...      ...
# 23965    Nisha Reddy  east       No
# 23966    Sunil Patel  east      Yes
# 23967    Parul Reddy  east       No
# 23968  Aarav Chauhan  east       No
# 23969   Harsha Patel  east      Yes
#
# [23970 rows x 10 columns]

# %%
#removing the Unnamed: 0 column

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df
# Out:
#                  a                  b      c  \
# 0      1800 sq.ft       64 L            3556
# 1      1300 sq.ft    70.20 L            5400
# 2      1108 sq.ft    43.67 L            3942
# 3      1742 sq.ft    1.27 Cr            7308
# 4       814 sq.ft       31 L            3808
# ...            ...                ...    ...
# 23965   864 sq.ft    46.65 L            5400
# 23966  1226 sq.ft    1.07 Cr            8793
# 23967  1520 sq.ft    1.25 Cr            8250
# 23968  1154 sq.ft    82.48 L            7148
# 23969  1600 sq.ft    1.76 Cr           11000
#
#                                                  d                q     t  \
# 0                        Srisailam Highway                      NaN   3.0
# 1                Gayatri Nagar-Saroornagar           3BHK Apartment  20.0
# 2      Ganesh Nagar Colony-Vanasthalipuram           2BHK Apartment  20.0
# 3              Sri Guru Raghavendra Colony           3BHK Apartment  27.0
# 4                               Beeramguda          2 BHK Apartment  25.0
# ...                                            ...              ...   ...
# 23965                           Rani Vihar          2 BHK Apartment  17.0
# 23966          Sharada Nagar-Dilsukh Nagar          3 BHK Apartment  17.0
# 23967                          Vimana Puri          3 BHK Apartment  17.0
# 23968                           Yakhutpura          2 BHK Apartment  17.0
# 23969                     North Kalyanpuri          3 BHK Apartment  17.0
#
#                    x     y        z
# 0             venkat  east  UnKnown
# 1               Arun  east       No
# 2       Lorgannaresh  east      Yes
# 3        Deepika Rao  east      Yes
# 4          Bijoy Rao  east      Yes
# ...              ...   ...      ...
# 23965    Nisha Reddy  east       No
# 23966    Sunil Patel  east      Yes
# 23967    Parul Reddy  east       No
# 23968  Aarav Chauhan  east       No
# 23969   Harsha Patel  east      Yes
#
# [23970 rows x 9 columns]

# %%
#giving column names

# %%
df.columns = ["Area_sq.ft","Price","Price_per_sq.ft","Locality","Type_of_house","Booking_start","Agent_Name","Direction","parking"]

# %%
df
# Out:
#         Area_sq.ft              Price  Price_per_sq.ft  \
# 0      1800 sq.ft       64 L                      3556
# 1      1300 sq.ft    70.20 L                      5400
# 2      1108 sq.ft    43.67 L                      3942
# 3      1742 sq.ft    1.27 Cr                      7308
# 4       814 sq.ft       31 L                      3808
# ...            ...                ...              ...
# 23965   864 sq.ft    46.65 L                      5400
# 23966  1226 sq.ft    1.07 Cr                      8793
# 23967  1520 sq.ft    1.25 Cr                      8250
# 23968  1154 sq.ft    82.48 L                      7148
# 23969  1600 sq.ft    1.76 Cr                     11000
#
#                                           Locality    Type_of_house  \
# 0                        Srisailam Highway                      NaN
# 1                Gayatri Nagar-Saroornagar           3BHK Apartment
# 2      Ganesh Nagar Colony-Vanasthalipuram           2BHK Apartment
# 3              Sri Guru Raghavendra Colony           3BHK Apartment
# 4                               Beeramguda          2 BHK Apartment
# ...                                            ...              ...
# 23965                           Rani Vihar          2 BHK Apartment
# 23966          Sharada Nagar-Dilsukh Nagar          3 BHK Apartment
# 23967                          Vimana Puri          3 BHK Apartment
# 23968                           Yakhutpura          2 BHK Apartment
# 23969                     North Kalyanpuri          3 BHK Apartment
#
#        Booking_start     Agent_Name Direction  parking
# 0                3.0         venkat      east  UnKnown
# 1               20.0           Arun      east       No
# 2               20.0   Lorgannaresh      east      Yes
# 3               27.0    Deepika Rao      east      Yes
# 4               25.0      Bijoy Rao      east      Yes
# ...              ...            ...       ...      ...
# 23965           17.0    Nisha Reddy      east       No
# 23966           17.0    Sunil Patel      east      Yes
# 23967           17.0    Parul Reddy      east       No
# 23968           17.0  Aarav Chauhan      east       No
# 23969           17.0   Harsha Patel      east      Yes
#
# [23970 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area_sq.ft       23970 non-null  object
#  1   Price            23970 non-null  object
#  2   Price_per_sq.ft  23970 non-null  int64
#  3   Locality         23970 non-null  object
#  4   Type_of_house    21341 non-null  object
#  5   Booking_start    23881 non-null  float64
#  6   Agent_Name       23945 non-null  object
#  7   Direction        23970 non-null  object
#  8   parking          23970 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 1.6+ MB

# %%
# changing data type of area_sq.ft

# %%
df["Area_sq.ft"] = df["Area_sq.ft"].str.rstrip(" sq.ft")

# %%
df["Area_sq.ft"] = df["Area_sq.ft"].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area_sq.ft       23970 non-null  int64
#  1   Price            23970 non-null  object
#  2   Price_per_sq.ft  23970 non-null  int64
#  3   Locality         23970 non-null  object
#  4   Type_of_house    21341 non-null  object
#  5   Booking_start    23881 non-null  float64
#  6   Agent_Name       23945 non-null  object
#  7   Direction        23970 non-null  object
#  8   parking          23970 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 1.6+ MB

# %%
# changing price datatype and changing order from lakhs to crores

# %%
df["Price"] = df["Price"].str.strip()

# %%
lst = []
for i in df['Price'].str.split():
    lst.append(i[1])
df["L/cr"] = lst

# %%
df
# Out:
#        Area_sq.ft    Price  Price_per_sq.ft  \
# 0            1800     64 L             3556
# 1            1300  70.20 L             5400
# 2            1108  43.67 L             3942
# 3            1742  1.27 Cr             7308
# 4             814     31 L             3808
# ...           ...      ...              ...
# 23965         864  46.65 L             5400
# 23966        1226  1.07 Cr             8793
# 23967        1520  1.25 Cr             8250
# 23968        1154  82.48 L             7148
# 23969        1600  1.76 Cr            11000
#
#                                           Locality    Type_of_house  \
# 0                        Srisailam Highway                      NaN
# 1                Gayatri Nagar-Saroornagar           3BHK Apartment
# 2      Ganesh Nagar Colony-Vanasthalipuram           2BHK Apartment
# 3              Sri Guru Raghavendra Colony           3BHK Apartment
# 4                               Beeramguda          2 BHK Apartment
# ...                                            ...              ...
# 23965                           Rani Vihar          2 BHK Apartment
# 23966          Sharada Nagar-Dilsukh Nagar          3 BHK Apartment
# 23967                          Vimana Puri          3 BHK Apartment
# 23968                           Yakhutpura          2 BHK Apartment
# 23969                     North Kalyanpuri          3 BHK Apartment
#
#        Booking_start     Agent_Name Direction  parking L/cr
# 0                3.0         venkat      east  UnKnown    L
# 1               20.0           Arun      east       No    L
# 2               20.0   Lorgannaresh      east      Yes    L
# 3               27.0    Deepika Rao      east      Yes   Cr
# 4               25.0      Bijoy Rao      east      Yes    L
# ...              ...            ...       ...      ...  ...
# 23965           17.0    Nisha Reddy      east       No    L
# 23966           17.0    Sunil Patel      east      Yes   Cr
# 23967           17.0    Parul Reddy      east       No   Cr
# 23968           17.0  Aarav Chauhan      east       No    L
# 23969           17.0   Harsha Patel      east      Yes   Cr
#
# [23970 rows x 10 columns]

# %%
df["Price"] = df["Price"].str.rstrip(" L")

# %%
df["Price"] = df["Price"].str.rstrip(" K")

# %%
df["Price"] = df["Price"].str.rstrip(" Cr")

# %%
df
# Out:
#        Area_sq.ft  Price  Price_per_sq.ft  \
# 0            1800     64             3556
# 1            1300  70.20             5400
# 2            1108  43.67             3942
# 3            1742   1.27             7308
# 4             814     31             3808
# ...           ...    ...              ...
# 23965         864  46.65             5400
# 23966        1226   1.07             8793
# 23967        1520   1.25             8250
# 23968        1154  82.48             7148
# 23969        1600   1.76            11000
#
#                                           Locality    Type_of_house  \
# 0                        Srisailam Highway                      NaN
# 1                Gayatri Nagar-Saroornagar           3BHK Apartment
# 2      Ganesh Nagar Colony-Vanasthalipuram           2BHK Apartment
# 3              Sri Guru Raghavendra Colony           3BHK Apartment
# 4                               Beeramguda          2 BHK Apartment
# ...                                            ...              ...
# 23965                           Rani Vihar          2 BHK Apartment
# 23966          Sharada Nagar-Dilsukh Nagar          3 BHK Apartment
# 23967                          Vimana Puri          3 BHK Apartment
# 23968                           Yakhutpura          2 BHK Apartment
# 23969                     North Kalyanpuri          3 BHK Apartment
#
#        Booking_start     Agent_Name Direction  parking L/cr
# 0                3.0         venkat      east  UnKnown    L
# 1               20.0           Arun      east       No    L
# 2               20.0   Lorgannaresh      east      Yes    L
# 3               27.0    Deepika Rao      east      Yes   Cr
# 4               25.0      Bijoy Rao      east      Yes    L
# ...              ...            ...       ...      ...  ...
# 23965           17.0    Nisha Reddy      east       No    L
# 23966           17.0    Sunil Patel      east      Yes   Cr
# 23967           17.0    Parul Reddy      east       No   Cr
# 23968           17.0  Aarav Chauhan      east       No    L
# 23969           17.0   Harsha Patel      east      Yes   Cr
#
# [23970 rows x 10 columns]

# %%
df["L/cr"].value_counts()
# Out:
# L     14514
# Cr     9454
# K         2
# Name: L/cr, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area_sq.ft       23970 non-null  int64
#  1   Price            23970 non-null  object
#  2   Price_per_sq.ft  23970 non-null  int64
#  3   Locality         23970 non-null  object
#  4   Type_of_house    21341 non-null  object
#  5   Booking_start    23881 non-null  float64
#  6   Agent_Name       23945 non-null  object
#  7   Direction        23970 non-null  object
#  8   parking          23970 non-null  object
#  9   L/cr             23970 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 1.8+ MB

# %%
df["Price"] = df["Price"].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area_sq.ft       23970 non-null  int64
#  1   Price            23970 non-null  float64
#  2   Price_per_sq.ft  23970 non-null  int64
#  3   Locality         23970 non-null  object
#  4   Type_of_house    21341 non-null  object
#  5   Booking_start    23881 non-null  float64
#  6   Agent_Name       23945 non-null  object
#  7   Direction        23970 non-null  object
#  8   parking          23970 non-null  object
#  9   L/cr             23970 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 1.8+ MB

# %%
lst3 = []
for i,j in zip(df['Price'],df["L/cr"]):
    if j == "Cr":
        lst3.append(i*(100))
    elif j == "K":
        lst3.append(round(i/100,3))
    else:
        lst3.append(i)

# %%
df["Price"] = lst3

# %%
df
# Out:
#        Area_sq.ft   Price  Price_per_sq.ft  \
# 0            1800   64.00             3556
# 1            1300   70.20             5400
# 2            1108   43.67             3942
# 3            1742  127.00             7308
# 4             814   31.00             3808
# ...           ...     ...              ...
# 23965         864   46.65             5400
# 23966        1226  107.00             8793
# 23967        1520  125.00             8250
# 23968        1154   82.48             7148
# 23969        1600  176.00            11000
#
#                                           Locality    Type_of_house  \
# 0                        Srisailam Highway                      NaN
# 1                Gayatri Nagar-Saroornagar           3BHK Apartment
# 2      Ganesh Nagar Colony-Vanasthalipuram           2BHK Apartment
# 3              Sri Guru Raghavendra Colony           3BHK Apartment
# 4                               Beeramguda          2 BHK Apartment
# ...                                            ...              ...
# 23965                           Rani Vihar          2 BHK Apartment
# 23966          Sharada Nagar-Dilsukh Nagar          3 BHK Apartment
# 23967                          Vimana Puri          3 BHK Apartment
# 23968                           Yakhutpura          2 BHK Apartment
# 23969                     North Kalyanpuri          3 BHK Apartment
#
#        Booking_start     Agent_Name Direction  parking L/cr
# 0                3.0         venkat      east  UnKnown    L
# 1               20.0           Arun      east       No    L
# 2               20.0   Lorgannaresh      east      Yes    L
# 3               27.0    Deepika Rao      east      Yes   Cr
# 4               25.0      Bijoy Rao      east      Yes    L
# ...              ...            ...       ...      ...  ...
# 23965           17.0    Nisha Reddy      east       No    L
# 23966           17.0    Sunil Patel      east      Yes   Cr
# 23967           17.0    Parul Reddy      east       No   Cr
# 23968           17.0  Aarav Chauhan      east       No    L
# 23969           17.0   Harsha Patel      east      Yes   Cr
#
# [23970 rows x 10 columns]

# %%
df.drop(columns="L/cr",inplace=True)

# %%
df
# Out:
#        Area_sq.ft   Price  Price_per_sq.ft  \
# 0            1800   64.00             3556
# 1            1300   70.20             5400
# 2            1108   43.67             3942
# 3            1742  127.00             7308
# 4             814   31.00             3808
# ...           ...     ...              ...
# 23965         864   46.65             5400
# 23966        1226  107.00             8793
# 23967        1520  125.00             8250
# 23968        1154   82.48             7148
# 23969        1600  176.00            11000
#
#                                           Locality    Type_of_house  \
# 0                        Srisailam Highway                      NaN
# 1                Gayatri Nagar-Saroornagar           3BHK Apartment
# 2      Ganesh Nagar Colony-Vanasthalipuram           2BHK Apartment
# 3              Sri Guru Raghavendra Colony           3BHK Apartment
# 4                               Beeramguda          2 BHK Apartment
# ...                                            ...              ...
# 23965                           Rani Vihar          2 BHK Apartment
# 23966          Sharada Nagar-Dilsukh Nagar          3 BHK Apartment
# 23967                          Vimana Puri          3 BHK Apartment
# 23968                           Yakhutpura          2 BHK Apartment
# 23969                     North Kalyanpuri          3 BHK Apartment
#
#        Booking_start     Agent_Name Direction  parking
# 0                3.0         venkat      east  UnKnown
# 1               20.0           Arun      east       No
# 2               20.0   Lorgannaresh      east      Yes
# 3               27.0    Deepika Rao      east      Yes
# 4               25.0      Bijoy Rao      east      Yes
# ...              ...            ...       ...      ...
# 23965           17.0    Nisha Reddy      east       No
# 23966           17.0    Sunil Patel      east      Yes
# 23967           17.0    Parul Reddy      east       No
# 23968           17.0  Aarav Chauhan      east       No
# 23969           17.0   Harsha Patel      east      Yes
#
# [23970 rows x 9 columns]

# %%
#creaating two new columnms from the type of house

# %%
df["Type_of_house"] = df["Type_of_house"].str.replace(" ","")

# %%
df["Type_of_house"].value_counts()
# Out:
# 3BHKApartment       10868
# 2BHKApartment        7517
# 4BHKApartment        1786
# 4BHKVilla             460
# 2BHKVilla             276
# 3BHKVilla             267
# 1BHKApartment         132
# 2BHKBuilder            13
# 5BHKApartment           8
# 1BHKVilla               6
# 2BHKBuilderFloor        5
# 3BHKBuilderFloor        1
# 3BHKBuilder             1
# 4BHKBuilder             1
# Name: Type_of_house, dtype: int64

# %%
# correcting the invalid data
df["Type_of_house"] = df["Type_of_house"].str.replace("K","K ")

# %%
df["Type_of_house"].value_counts()
# Out:
# 3BHK Apartment       10868
# 2BHK Apartment        7517
# 4BHK Apartment        1786
# 4BHK Villa             460
# 2BHK Villa             276
# 3BHK Villa             267
# 1BHK Apartment         132
# 2BHK Builder            13
# 5BHK Apartment           8
# 1BHK Villa               6
# 2BHK BuilderFloor        5
# 3BHK BuilderFloor        1
# 3BHK Builder             1
# 4BHK Builder             1
# Name: Type_of_house, dtype: int64

# %%
df
# Out:
#        Area_sq.ft   Price  Price_per_sq.ft  \
# 0            1800   64.00             3556
# 1            1300   70.20             5400
# 2            1108   43.67             3942
# 3            1742  127.00             7308
# 4             814   31.00             3808
# ...           ...     ...              ...
# 23965         864   46.65             5400
# 23966        1226  107.00             8793
# 23967        1520  125.00             8250
# 23968        1154   82.48             7148
# 23969        1600  176.00            11000
#
#                                           Locality   Type_of_house  \
# 0                        Srisailam Highway                     NaN
# 1                Gayatri Nagar-Saroornagar          3BHK Apartment
# 2      Ganesh Nagar Colony-Vanasthalipuram          2BHK Apartment
# 3              Sri Guru Raghavendra Colony          3BHK Apartment
# 4                               Beeramguda          2BHK Apartment
# ...                                            ...             ...
# 23965                           Rani Vihar          2BHK Apartment
# 23966          Sharada Nagar-Dilsukh Nagar          3BHK Apartment
# 23967                          Vimana Puri          3BHK Apartment
# 23968                           Yakhutpura          2BHK Apartment
# 23969                     North Kalyanpuri          3BHK Apartment
#
#        Booking_start     Agent_Name Direction  parking
# 0                3.0         venkat      east  UnKnown
# 1               20.0           Arun      east       No
# 2               20.0   Lorgannaresh      east      Yes
# 3               27.0    Deepika Rao      east      Yes
# 4               25.0      Bijoy Rao      east      Yes
# ...              ...            ...       ...      ...
# 23965           17.0    Nisha Reddy      east       No
# 23966           17.0    Sunil Patel      east      Yes
# 23967           17.0    Parul Reddy      east       No
# 23968           17.0  Aarav Chauhan      east       No
# 23969           17.0   Harsha Patel      east      Yes
#
# [23970 rows x 9 columns]

# %%
# filling nan values with plot 
df["Type_of_house"]=df["Type_of_house"].fillna("Plot")

# %%
df
# Out:
#        Area_sq.ft   Price  Price_per_sq.ft  \
# 0            1800   64.00             3556
# 1            1300   70.20             5400
# 2            1108   43.67             3942
# 3            1742  127.00             7308
# 4             814   31.00             3808
# ...           ...     ...              ...
# 23965         864   46.65             5400
# 23966        1226  107.00             8793
# 23967        1520  125.00             8250
# 23968        1154   82.48             7148
# 23969        1600  176.00            11000
#
#                                           Locality   Type_of_house  \
# 0                        Srisailam Highway                    Plot
# 1                Gayatri Nagar-Saroornagar          3BHK Apartment
# 2      Ganesh Nagar Colony-Vanasthalipuram          2BHK Apartment
# 3              Sri Guru Raghavendra Colony          3BHK Apartment
# 4                               Beeramguda          2BHK Apartment
# ...                                            ...             ...
# 23965                           Rani Vihar          2BHK Apartment
# 23966          Sharada Nagar-Dilsukh Nagar          3BHK Apartment
# 23967                          Vimana Puri          3BHK Apartment
# 23968                           Yakhutpura          2BHK Apartment
# 23969                     North Kalyanpuri          3BHK Apartment
#
#        Booking_start     Agent_Name Direction  parking
# 0                3.0         venkat      east  UnKnown
# 1               20.0           Arun      east       No
# 2               20.0   Lorgannaresh      east      Yes
# 3               27.0    Deepika Rao      east      Yes
# 4               25.0      Bijoy Rao      east      Yes
# ...              ...            ...       ...      ...
# 23965           17.0    Nisha Reddy      east       No
# 23966           17.0    Sunil Patel      east      Yes
# 23967           17.0    Parul Reddy      east       No
# 23968           17.0  Aarav Chauhan      east       No
# 23969           17.0   Harsha Patel      east      Yes
#
# [23970 rows x 9 columns]

# %%
df["Type_of_house"].value_counts()
# Out:
# 3BHK Apartment       10868
# 2BHK Apartment        7517
# Plot                  2629
# 4BHK Apartment        1786
# 4BHK Villa             460
# 2BHK Villa             276
# 3BHK Villa             267
# 1BHK Apartment         132
# 2BHK Builder            13
# 5BHK Apartment           8
# 1BHK Villa               6
# 2BHK BuilderFloor        5
# 3BHK BuilderFloor        1
# 3BHK Builder             1
# 4BHK Builder             1
# Name: Type_of_house, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area_sq.ft       23970 non-null  int64
#  1   Price            23970 non-null  float64
#  2   Price_per_sq.ft  23970 non-null  int64
#  3   Locality         23970 non-null  object
#  4   Type_of_house    23970 non-null  object
#  5   Booking_start    23881 non-null  float64
#  6   Agent_Name       23945 non-null  object
#  7   Direction        23970 non-null  object
#  8   parking          23970 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 1.6+ MB

# %%
df.to_csv("clean_dataset.csv")

# %%
df = pd.read_csv("clean_dataset.csv")

# %%
df
# Out:
#        Unnamed: 0  Area_sq.ft   Price  Price_per_sq.ft  \
# 0               0        1800   64.00             3556
# 1               1        1300   70.20             5400
# 2               2        1108   43.67             3942
# 3               3        1742  127.00             7308
# 4               4         814   31.00             3808
# ...           ...         ...     ...              ...
# 23965       23965         864   46.65             5400
# 23966       23966        1226  107.00             8793
# 23967       23967        1520  125.00             8250
# 23968       23968        1154   82.48             7148
# 23969       23969        1600  176.00            11000
#
#                                           Locality   Type_of_house  \
# 0                        Srisailam Highway                    Plot
# 1                Gayatri Nagar-Saroornagar          3BHK Apartment
# 2      Ganesh Nagar Colony-Vanasthalipuram          2BHK Apartment
# 3              Sri Guru Raghavendra Colony          3BHK Apartment
# 4                               Beeramguda          2BHK Apartment
# ...                                            ...             ...
# 23965                           Rani Vihar          2BHK Apartment
# 23966          Sharada Nagar-Dilsukh Nagar          3BHK Apartment
# 23967                          Vimana Puri          3BHK Apartment
# 23968                           Yakhutpura          2BHK Apartment
# 23969                     North Kalyanpuri          3BHK Apartment
#
#        Booking_start     Agent_Name Direction  parking
# 0                3.0         venkat      east  UnKnown
# 1               20.0           Arun      east       No
# 2               20.0   Lorgannaresh      east      Yes
# 3               27.0    Deepika Rao      east      Yes
# 4               25.0      Bijoy Rao      east      Yes
# ...              ...            ...       ...      ...
# 23965           17.0    Nisha Reddy      east       No
# 23966           17.0    Sunil Patel      east      Yes
# 23967           17.0    Parul Reddy      east       No
# 23968           17.0  Aarav Chauhan      east       No
# 23969           17.0   Harsha Patel      east      Yes
#
# [23970 rows x 10 columns]

# %%
df.drop(columns="Unnamed: 0",inplace=True)

# %%
df
# Out:
#        Area_sq.ft   Price  Price_per_sq.ft  \
# 0            1800   64.00             3556
# 1            1300   70.20             5400
# 2            1108   43.67             3942
# 3            1742  127.00             7308
# 4             814   31.00             3808
# ...           ...     ...              ...
# 23965         864   46.65             5400
# 23966        1226  107.00             8793
# 23967        1520  125.00             8250
# 23968        1154   82.48             7148
# 23969        1600  176.00            11000
#
#                                           Locality   Type_of_house  \
# 0                        Srisailam Highway                    Plot
# 1                Gayatri Nagar-Saroornagar          3BHK Apartment
# 2      Ganesh Nagar Colony-Vanasthalipuram          2BHK Apartment
# 3              Sri Guru Raghavendra Colony          3BHK Apartment
# 4                               Beeramguda          2BHK Apartment
# ...                                            ...             ...
# 23965                           Rani Vihar          2BHK Apartment
# 23966          Sharada Nagar-Dilsukh Nagar          3BHK Apartment
# 23967                          Vimana Puri          3BHK Apartment
# 23968                           Yakhutpura          2BHK Apartment
# 23969                     North Kalyanpuri          3BHK Apartment
#
#        Booking_start     Agent_Name Direction  parking
# 0                3.0         venkat      east  UnKnown
# 1               20.0           Arun      east       No
# 2               20.0   Lorgannaresh      east      Yes
# 3               27.0    Deepika Rao      east      Yes
# 4               25.0      Bijoy Rao      east      Yes
# ...              ...            ...       ...      ...
# 23965           17.0    Nisha Reddy      east       No
# 23966           17.0    Sunil Patel      east      Yes
# 23967           17.0    Parul Reddy      east       No
# 23968           17.0  Aarav Chauhan      east       No
# 23969           17.0   Harsha Patel      east      Yes
#
# [23970 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area_sq.ft       23970 non-null  int64
#  1   Price            23970 non-null  float64
#  2   Price_per_sq.ft  23970 non-null  int64
#  3   Locality         23970 non-null  object
#  4   Type_of_house    23970 non-null  object
#  5   Booking_start    23881 non-null  float64
#  6   Agent_Name       23945 non-null  object
#  7   Direction        23970 non-null  object
#  8   parking          23970 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 1.6+ MB

# %%
# Filling null values in Booking_start,Agent_name

# %%
df["Booking_start"] = df["Booking_start"].fillna(df["Booking_start"].mode()[0])

# %%
df["Agent_Name"] = df["Agent_Name"].fillna("UnKnown")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area_sq.ft       23970 non-null  int64
#  1   Price            23970 non-null  float64
#  2   Price_per_sq.ft  23970 non-null  int64
#  3   Locality         23970 non-null  object
#  4   Type_of_house    23970 non-null  object
#  5   Booking_start    23970 non-null  float64
#  6   Agent_Name       23970 non-null  object
#  7   Direction        23970 non-null  object
#  8   parking          23970 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 1.6+ MB

# %%
df
# Out:
#        Area_sq.ft   Price  Price_per_sq.ft  \
# 0            1800   64.00             3556
# 1            1300   70.20             5400
# 2            1108   43.67             3942
# 3            1742  127.00             7308
# 4             814   31.00             3808
# ...           ...     ...              ...
# 23965         864   46.65             5400
# 23966        1226  107.00             8793
# 23967        1520  125.00             8250
# 23968        1154   82.48             7148
# 23969        1600  176.00            11000
#
#                                           Locality   Type_of_house  \
# 0                        Srisailam Highway                    Plot
# 1                Gayatri Nagar-Saroornagar          3BHK Apartment
# 2      Ganesh Nagar Colony-Vanasthalipuram          2BHK Apartment
# 3              Sri Guru Raghavendra Colony          3BHK Apartment
# 4                               Beeramguda          2BHK Apartment
# ...                                            ...             ...
# 23965                           Rani Vihar          2BHK Apartment
# 23966          Sharada Nagar-Dilsukh Nagar          3BHK Apartment
# 23967                          Vimana Puri          3BHK Apartment
# 23968                           Yakhutpura          2BHK Apartment
# 23969                     North Kalyanpuri          3BHK Apartment
#
#        Booking_start     Agent_Name Direction  parking
# 0                3.0         venkat      east  UnKnown
# 1               20.0           Arun      east       No
# 2               20.0   Lorgannaresh      east      Yes
# 3               27.0    Deepika Rao      east      Yes
# 4               25.0      Bijoy Rao      east      Yes
# ...              ...            ...       ...      ...
# 23965           17.0    Nisha Reddy      east       No
# 23966           17.0    Sunil Patel      east      Yes
# 23967           17.0    Parul Reddy      east       No
# 23968           17.0  Aarav Chauhan      east       No
# 23969           17.0   Harsha Patel      east      Yes
#
# [23970 rows x 9 columns]

# %%
def column_split(n):
    return n.split()[0]

# %%
# extracting the type_bhk column from the type_of_house column

df["Type_BHK"] = df["Type_of_house"].apply(column_split)

# %%
df
# Out:
#        Area_sq.ft   Price  Price_per_sq.ft  \
# 0            1800   64.00             3556
# 1            1300   70.20             5400
# 2            1108   43.67             3942
# 3            1742  127.00             7308
# 4             814   31.00             3808
# ...           ...     ...              ...
# 23965         864   46.65             5400
# 23966        1226  107.00             8793
# 23967        1520  125.00             8250
# 23968        1154   82.48             7148
# 23969        1600  176.00            11000
#
#                                           Locality   Type_of_house  \
# 0                        Srisailam Highway                    Plot
# 1                Gayatri Nagar-Saroornagar          3BHK Apartment
# 2      Ganesh Nagar Colony-Vanasthalipuram          2BHK Apartment
# 3              Sri Guru Raghavendra Colony          3BHK Apartment
# 4                               Beeramguda          2BHK Apartment
# ...                                            ...             ...
# 23965                           Rani Vihar          2BHK Apartment
# 23966          Sharada Nagar-Dilsukh Nagar          3BHK Apartment
# 23967                          Vimana Puri          3BHK Apartment
# 23968                           Yakhutpura          2BHK Apartment
# 23969                     North Kalyanpuri          3BHK Apartment
#
#        Booking_start     Agent_Name Direction  parking Type_BHK
# 0                3.0         venkat      east  UnKnown     Plot
# 1               20.0           Arun      east       No     3BHK
# 2               20.0   Lorgannaresh      east      Yes     2BHK
# 3               27.0    Deepika Rao      east      Yes     3BHK
# 4               25.0      Bijoy Rao      east      Yes     2BHK
# ...              ...            ...       ...      ...      ...
# 23965           17.0    Nisha Reddy      east       No     2BHK
# 23966           17.0    Sunil Patel      east      Yes     3BHK
# 23967           17.0    Parul Reddy      east       No     3BHK
# 23968           17.0  Aarav Chauhan      east       No     2BHK
# 23969           17.0   Harsha Patel      east      Yes     3BHK
#
# [23970 rows x 10 columns]

# %%
def c_split(n):
    if len(n.split())>1:
        return n.split()[1]
    else:
        return n.split()[0]

# %%
# creating the type_of_house column from the type_of_house

df["Type_Of_House"] = df["Type_of_house"].apply(c_split)

# %%
df
# Out:
#        Area_sq.ft   Price  Price_per_sq.ft  \
# 0            1800   64.00             3556
# 1            1300   70.20             5400
# 2            1108   43.67             3942
# 3            1742  127.00             7308
# 4             814   31.00             3808
# ...           ...     ...              ...
# 23965         864   46.65             5400
# 23966        1226  107.00             8793
# 23967        1520  125.00             8250
# 23968        1154   82.48             7148
# 23969        1600  176.00            11000
#
#                                           Locality   Type_of_house  \
# 0                        Srisailam Highway                    Plot
# 1                Gayatri Nagar-Saroornagar          3BHK Apartment
# 2      Ganesh Nagar Colony-Vanasthalipuram          2BHK Apartment
# 3              Sri Guru Raghavendra Colony          3BHK Apartment
# 4                               Beeramguda          2BHK Apartment
# ...                                            ...             ...
# 23965                           Rani Vihar          2BHK Apartment
# 23966          Sharada Nagar-Dilsukh Nagar          3BHK Apartment
# 23967                          Vimana Puri          3BHK Apartment
# 23968                           Yakhutpura          2BHK Apartment
# 23969                     North Kalyanpuri          3BHK Apartment
#
#        Booking_start     Agent_Name Direction  parking Type_BHK Type_Of_House
# 0                3.0         venkat      east  UnKnown     Plot          Plot
# 1               20.0           Arun      east       No     3BHK     Apartment
# 2               20.0   Lorgannaresh      east      Yes     2BHK     Apartment
# 3               27.0    Deepika Rao      east      Yes     3BHK     Apartment
# 4               25.0      Bijoy Rao      east      Yes     2BHK     Apartment
# ...              ...            ...       ...      ...      ...           ...
# 23965           17.0    Nisha Reddy      east       No     2BHK     Apartment
# 23966           17.0    Sunil Patel      east      Yes     3BHK     Apartment
# 23967           17.0    Parul Reddy      east       No     3BHK     Apartment
# 23968           17.0  Aarav Chauhan      east       No     2BHK     Apartment
# 23969           17.0   Harsha Patel      east      Yes     3BHK     Apartment
#
# [23970 rows x 11 columns]

# %%
# dropping the type_of_house

# %%
df.drop(columns="Type_of_house",inplace=True)

# %%
df
# Out:
#        Area_sq.ft   Price  Price_per_sq.ft  \
# 0            1800   64.00             3556
# 1            1300   70.20             5400
# 2            1108   43.67             3942
# 3            1742  127.00             7308
# 4             814   31.00             3808
# ...           ...     ...              ...
# 23965         864   46.65             5400
# 23966        1226  107.00             8793
# 23967        1520  125.00             8250
# 23968        1154   82.48             7148
# 23969        1600  176.00            11000
#
#                                           Locality  Booking_start  \
# 0                        Srisailam Highway                    3.0
# 1                Gayatri Nagar-Saroornagar                   20.0
# 2      Ganesh Nagar Colony-Vanasthalipuram                   20.0
# 3              Sri Guru Raghavendra Colony                   27.0
# 4                               Beeramguda                   25.0
# ...                                            ...            ...
# 23965                           Rani Vihar                   17.0
# 23966          Sharada Nagar-Dilsukh Nagar                   17.0
# 23967                          Vimana Puri                   17.0
# 23968                           Yakhutpura                   17.0
# 23969                     North Kalyanpuri                   17.0
#
#           Agent_Name Direction  parking Type_BHK Type_Of_House
# 0             venkat      east  UnKnown     Plot          Plot
# 1               Arun      east       No     3BHK     Apartment
# 2       Lorgannaresh      east      Yes     2BHK     Apartment
# 3        Deepika Rao      east      Yes     3BHK     Apartment
# 4          Bijoy Rao      east      Yes     2BHK     Apartment
# ...              ...       ...      ...      ...           ...
# 23965    Nisha Reddy      east       No     2BHK     Apartment
# 23966    Sunil Patel      east      Yes     3BHK     Apartment
# 23967    Parul Reddy      east       No     3BHK     Apartment
# 23968  Aarav Chauhan      east       No     2BHK     Apartment
# 23969   Harsha Patel      east      Yes     3BHK     Apartment
#
# [23970 rows x 10 columns]

# %%
# changing data type of booking_start column

df["Booking_start"] = df["Booking_start"].astype('int32')

# %%
df
# Out:
#        Area_sq.ft   Price  Price_per_sq.ft  \
# 0            1800   64.00             3556
# 1            1300   70.20             5400
# 2            1108   43.67             3942
# 3            1742  127.00             7308
# 4             814   31.00             3808
# ...           ...     ...              ...
# 23965         864   46.65             5400
# 23966        1226  107.00             8793
# 23967        1520  125.00             8250
# 23968        1154   82.48             7148
# 23969        1600  176.00            11000
#
#                                           Locality  Booking_start  \
# 0                        Srisailam Highway                      3
# 1                Gayatri Nagar-Saroornagar                     20
# 2      Ganesh Nagar Colony-Vanasthalipuram                     20
# 3              Sri Guru Raghavendra Colony                     27
# 4                               Beeramguda                     25
# ...                                            ...            ...
# 23965                           Rani Vihar                     17
# 23966          Sharada Nagar-Dilsukh Nagar                     17
# 23967                          Vimana Puri                     17
# 23968                           Yakhutpura                     17
# 23969                     North Kalyanpuri                     17
#
#           Agent_Name Direction  parking Type_BHK Type_Of_House
# 0             venkat      east  UnKnown     Plot          Plot
# 1               Arun      east       No     3BHK     Apartment
# 2       Lorgannaresh      east      Yes     2BHK     Apartment
# 3        Deepika Rao      east      Yes     3BHK     Apartment
# 4          Bijoy Rao      east      Yes     2BHK     Apartment
# ...              ...       ...      ...      ...           ...
# 23965    Nisha Reddy      east       No     2BHK     Apartment
# 23966    Sunil Patel      east      Yes     3BHK     Apartment
# 23967    Parul Reddy      east       No     3BHK     Apartment
# 23968  Aarav Chauhan      east       No     2BHK     Apartment
# 23969   Harsha Patel      east      Yes     3BHK     Apartment
#
# [23970 rows x 10 columns]

# %%
# saving this cleaned dataframe for the further use

df.to_csv("clean_ready_to_plot.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("clean_ready_to_plot.csv")

# %% [markdown]
# # Uni Variate Ploting

# %%
# type of houses

# %%
fig, ax = plt.subplots(1, 2, figsize=(11, 6))
# count plot
sns.countplot(data=df, x="Type_Of_House", ax=ax[0])
ax[0].bar_label(ax[0].containers[0], label_type='edge')  # Show count labels on bars
ax[0].set_title("Count of House Types",fontsize=14)

custom_colors = ["#DC8665","#138086","#534666","#CD7672","#138086","#C4AD9D","#0274BD"]

ax[1].pie(df["Type_Of_House"].value_counts(),labels=house_counts.index, autopct='%1.1f%%', colors=custom_colors,startangle=140)
ax[1].set_title("Distribution of House Types",fontsize = 14)

plt.tight_layout()
plt.show()

# %%
ax = sns.countplot(data = df,x="Direction",order=["north","east","west","north east","south"])
ax.bar_label(ax.containers[0], label_type='edge')


plt.xlabel("House Facing Direction", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.title("Direction of houses", fontsize=14)
plt.show()

# %%
ax = sns.countplot(data = df,x="parking",palette=custom_colors)
ax.bar_label(ax.containers[0], label_type='edge')

plt.xlabel("House Parking", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.title("Parking Availability", fontsize=14)
plt.show()

# %%
import numpy as np

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

sns.barplot(data=df,x = "Type_BHK",y="Area_sq.ft",palette=custom_colors,errwidth=False,ax=ax[0])
ax[0].bar_label(ax[0].containers[0], label_type='edge')
ax[0].set_title("Average sq.ft of Houses",fontsize=14)

sns.barplot(data=df,x = "Type_BHK",y="Area_sq.ft",palette=custom_colors,estimator= np.max,errwidth=False,ax=ax[1])
ax[1].bar_label(ax[1].containers[0], label_type='edge')
ax[1].set_title("Max sq.ft of Houses",fontsize=14)
plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize=(22, 6))

sns.barplot(data=df,x = "Type_BHK",y="Area_sq.ft",palette=custom_colors,errwidth=False,ax=ax[0])
ax[0].bar_label(ax[0].containers[0], label_type='edge')
ax[0].set_title("Average sq.ft of Houses",fontsize=14)

sns.barplot(data=df,x = "Type_BHK",y="Area_sq.ft",palette=custom_colors,estimator=np.max,errwidth=False,ax=ax[1])
ax[1].bar_label(ax[1].containers[0], label_type='edge')
ax[1].set_title("Max sq.ft of Houses",fontsize=14)

sns.barplot(data=df,x = "Type_BHK",y="Area_sq.ft",palette=custom_colors,estimator=np.min,errwidth=False,ax=ax[2])
ax[2].bar_label(ax[2].containers[0], label_type='edge')
ax[2].set_title("Min sq.ft of Houses",fontsize=14)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define categories and values (assign values yourself)
categories = ["Price", "Price per Sq. Ft.", "Area"]
apartments =   # Assign values for Apartments
plots = [ ]       # Assign values for Plots

x = np.arange(len(categories))  # X-axis positions
width = 0.3  # Bar width

# Create grouped bar chart
fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(x - width/2, apartments, width, label="Apartments", color="teal")
ax.bar(x + width/2, plots, width, label="Plots", color="orange")

# Labels and title
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylabel("Values")
ax.set_title("Comparison of Apartments vs. Plots")
ax.legend()

# Display values on bars
for i, v in enumerate(apartments):
    ax.text(i - width/2, v + 2, str(v), ha='center', fontsize=10)
for i, v in enumerate(plots):
    ax.text(i + width/2, v + 2, str(v), ha='center', fontsize=10)

plt.show()

# %%
b1 = df[df["Type_BHK"]=="1BHK"]
b2 = df[df["Type_BHK"]=="2BHK"]
b3 = df[df["Type_BHK"]=="3BHK"]
b4 = df[df["Type_BHK"]=="4BHK"]
b5 = df[df["Type_BHK"]=="5BHK"]

# %%
fig, ax = plt.subplots(1, 5, figsize=(22, 6))
sns.scatterplot(data = b1,x="Area_sq.ft",y = "Price",hue="Type_Of_House",ax=ax[0])
ax[0].set_title("1 BHK",fontsize=14)
sns.scatterplot(data = b2,x="Area_sq.ft",y = "Price",hue="Type_Of_House",ax=ax[1])
ax[1].set_title("2 BHK",fontsize=14)
sns.scatterplot(data = b3,x="Area_sq.ft",y = "Price",hue="Type_Of_House",ax=ax[2])
ax[2].set_title("3 BHK",fontsize=14)
sns.scatterplot(data = b4,x="Area_sq.ft",y = "Price",hue="Type_Of_House",ax=ax[3])
ax[3].set_title("4 BHK",fontsize=14)
sns.scatterplot(data = b5,x="Area_sq.ft",y = "Price",hue="Type_Of_House",ax=ax[4])
ax[4].set_title("5 BHK",fontsize=14)

plt.show()

# %%
df
# Out:
#        Unnamed: 0  Area_sq.ft   Price  Price_per_sq.ft  \
# 0               0        1800   64.00             3556
# 1               1        1300   70.20             5400
# 2               2        1108   43.67             3942
# 3               3        1742  127.00             7308
# 4               4         814   31.00             3808
# ...           ...         ...     ...              ...
# 23965       23965         864   46.65             5400
# 23966       23966        1226  107.00             8793
# 23967       23967        1520  125.00             8250
# 23968       23968        1154   82.48             7148
# 23969       23969        1600  176.00            11000
#
#                                           Locality  Booking_start  \
# 0                        Srisailam Highway                      3
# 1                Gayatri Nagar-Saroornagar                     20
# 2      Ganesh Nagar Colony-Vanasthalipuram                     20
# 3              Sri Guru Raghavendra Colony                     27
# 4                               Beeramguda                     25
# ...                                            ...            ...
# 23965                           Rani Vihar                     17
# 23966          Sharada Nagar-Dilsukh Nagar                     17
# 23967                          Vimana Puri                     17
# 23968                           Yakhutpura                     17
# 23969                     North Kalyanpuri                     17
#
#           Agent_Name Direction  parking Type_BHK Type_Of_House
# 0             venkat      east  UnKnown     Plot          Plot
# 1               Arun      east       No     3BHK     Apartment
# 2       Lorgannaresh      east      Yes     2BHK     Apartment
# 3        Deepika Rao      east      Yes     3BHK     Apartment
# 4          Bijoy Rao      east      Yes     2BHK     Apartment
# ...              ...       ...      ...      ...           ...
# 23965    Nisha Reddy      east       No     2BHK     Apartment
# 23966    Sunil Patel      east      Yes     3BHK     Apartment
# 23967    Parul Reddy      east       No     3BHK     Apartment
# 23968  Aarav Chauhan      east       No     2BHK     Apartment
# 23969   Harsha Patel      east      Yes     3BHK     Apartment
#
# [23970 rows x 11 columns]

# %%
ax = sns.barplot(data=df,x="Type_Of_House",y="Price",palette=custom_colors2,errwidth=False)
ax.bar_label(ax.containers[0], label_type='edge')
plt.xlabel("Type_Of_House", fontsize=12)
plt.ylabel("Price", fontsize=12)
plt.title("Average Prices Of Different House Types", fontsize=14)
plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize=(22, 6))
sns.kdeplot(data=df[df["Type_Of_House"]=="Apartment"],x="Price",fill=True,color="orange",ax=ax[0])
ax[0].set_title("Apartment Price Distribution",fontsize=14)

sns.kdeplot(data=df[df["Type_Of_House"]=="Villa"],x="Price",fill=True,shade=True,color="purple",ax=ax[1])
ax[1].set_title("Villa Price Distribution",fontsize=14)

sns.kdeplot(data=df[df["Type_Of_House"]=="Plot"],x="Price",fill=True,shade=True,color="green",ax=ax[2])
ax[2].set_title("Plot Price Distribution",fontsize=14)


plt.show()

# %%
top_10 = df['Locality'].value_counts().head(10).index
top_10_df = df[df['Locality'].isin(top_cities)]

# %%
ax = sns.countplot(data=top_10_df,x="Locality")
ax.bar_label(ax.containers[0], label_type='edge')

p = top_10_df["Locality"].value_counts()

for bar, label in zip(ax.containers[0], p.index):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height()/2, label, ha='center', va='center', rotation=90)
ax.set_xticks([])


plt.figure(figsize=(12,8))
plt.show()

# %%
df1 = df[df["Type_Of_House"]=="Apartment"]
df2 = df[df["Type_Of_House"]=="Plot"]

# %%
top_cities = df1['Locality'].value_counts().head(10).index
top_cities_p = df2['Locality'].value_counts().head(10).index

# %%
top_cities_df = df1[df1['Locality'].isin(top_cities)]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
top_cities_df = df[df['Locality'].isin(top_cities)]
top_cities_p_df = df[df['Locality'].isin(top_cities_p)]

# %%
top_cities_df
# Out:
#        Unnamed: 0  Area_sq.ft   Price  Price_per_sq.ft  \
# 8               8        1284  136.00            10625
# 9               9        1822  200.00            10977
# 19             19        1585  140.00             8833
# 26             26        1636  184.00            11249
# 30             30        1585  140.00             8833
# ...           ...         ...     ...              ...
# 23850       23850         920   82.00             8913
# 23881       23881        1377  120.00             8751
# 23910       23910        1476  139.00             9417
# 23920       23920        1236   83.43             6750
# 23940       23940        1884  177.00             9395
#
#                       Locality  Booking_start         Agent_Name   Direction  \
# 8      Serilingampally                     17        Ankush Iyer       north
# 9             Tellapur                     17   Shivani Tripathi       north
# 19          Bachupally                      3               Asha        east
# 26            Kondapur                      2  Ravi Popuri(PRKS)       south
# 30          Bachupally                      3               Asha  north east
# ...                        ...            ...                ...         ...
# 23850     Chanda Nagar                      4               Asha  north east
# 23881  Serilingampally                     21         Deepshikha        east
# 23910         Tellapur                      8           SR Reddy        east
# 23920         Kondapur                     17          Jaya Iyer        east
# 23940         Tellapur                      8           SR Reddy        east
#
#       parking Type_BHK Type_Of_House
# 8         Yes     3BHK     Apartment
# 9          No     3BHK     Apartment
# 19        Yes     3BHK     Apartment
# 26        Yes     3BHK     Apartment
# 30         No     3BHK     Apartment
# ...       ...      ...           ...
# 23850     Yes     2BHK     Apartment
# 23881     Yes     3BHK     Apartment
# 23910      No     3BHK     Apartment
# 23920     Yes     3BHK     Apartment
# 23940     Yes     3BHK     Apartment
#
# [2648 rows x 11 columns]

# %%
top_cities_p_df
# Out:
#        Unnamed: 0  Area_sq.ft  Price  Price_per_sq.ft  \
# 0               0        1800  64.00             3556
# 17             17        2250  60.00             2667
# 39             39        2400  64.00             2667
# 44             44        1500  40.00             2667
# 45             45        1485  26.00             1751
# ...           ...         ...    ...              ...
# 23791       23791        1350  26.25             1944
# 23820       23820        1800  64.00             3556
# 23824       23824        1350  16.87             1250
# 23880       23880        1800  50.00             2778
# 23914       23914        1800  34.99             1944
#
#                         Locality  Booking_start             Agent_Name  \
# 0      Srisailam Highway                      3                 venkat
# 17          Shankarpalli                      5          Yadavalligopi
# 39          Shankarpalli                      6          Yadavalligopi
# 44             Tukkuguda                      5          Yadavalligopi
# 45               Kadthal                      5          Yadavalligopi
# ...                          ...            ...                    ...
# 23791            Kadthal                     25          Bhavesh Reddy
# 23820  Srisailam Highway                      3                 venkat
# 23824            Kadthal                     19  Ganapathy Subramanian
# 23880              Kandi                      3                 venkat
# 23914          Shadnagar                      9          Prajeeth Jain
#
#         Direction  parking Type_BHK Type_Of_House
# 0            east  UnKnown     Plot          Plot
# 17           east  UnKnown     Plot          Plot
# 39           east  UnKnown     Plot          Plot
# 44           east  UnKnown     Plot          Plot
# 45           east  UnKnown     Plot          Plot
# ...           ...      ...      ...           ...
# 23791        east  UnKnown     Plot          Plot
# 23820        east  UnKnown     Plot          Plot
# 23824        east  UnKnown     Plot          Plot
# 23880        east  UnKnown     Plot          Plot
# 23914  north east  UnKnown     Plot          Plot
#
# [1386 rows x 11 columns]

# %%
city_counts = top_cities_df["Locality"].value_counts()


fig, ax = plt.subplots(1, 2, figsize=(20,8))

sns.barplot(data=top_cities_df,x="Locality",y="Price",errwidth=False,ax=ax[0])
ax[0].bar_label(ax[0].containers[0], label_type='edge')
plt.xticks(rotation=90, ha="right")
ax[0].set_title("Avg Price of Apartments Among Top 10 Places",fontsize=14)

for bar, label in zip(ax[0].containers[0], city_counts.index):
    ax[0].text(bar.get_x() + bar.get_width()/2, bar.get_height()/2, label, ha='center', va='center', rotation=90)
ax[0].set_xticks([])
    
sns.barplot(data=top_cities_df,x="Locality",y="Price_per_sq.ft",errwidth=False,ax=ax[1])
ax[1].bar_label(ax[1].containers[0], label_type='edge')
plt.xticks(rotation=90, ha="right")

ax[1].set_title("Avg Price_per_sq.ft of Apartments Among Top 10 Places",fontsize=14)
for bar, label in zip(ax[1].containers[0], city_counts.index):
    ax[1].text(bar.get_x() + bar.get_width()/2, bar.get_height()/2, label, ha='center', va='center', rotation=90)

ax[1].set_xticks([])  # Remove x-axis labels





plt.show()

# %%
city_counts = top_cities_p_df["Locality"].value_counts()


fig, ax = plt.subplots(1, 2, figsize=(22, 10))

sns.barplot(data=top_cities_p_df,x="Locality",y="Price",errwidth=False,ax=ax[0])
ax[0].bar_label(ax[0].containers[0], label_type='edge')
plt.xticks(rotation=90, ha="right")
ax[0].set_title("Avg Price of Plots Among Top 10 Places",fontsize=14)

for bar, label in zip(ax[0].containers[0], city_counts.index):
    ax[0].text(bar.get_x() + bar.get_width()/2, bar.get_height()/2, label, ha='center', va='center', rotation=90)
ax[0].set_xticks([])
    
sns.barplot(data=top_cities_p_df,x="Locality",y="Price_per_sq.ft",errwidth=False,ax=ax[1])
ax[1].bar_label(ax[1].containers[0], label_type='edge')
plt.xticks(rotation=90, ha="right")

ax[1].set_title("Avg Price_per_sq.ft of Plots Among Top 10 Places",fontsize=14)
for bar, label in zip(ax[1].containers[0], city_counts.index):
    ax[1].text(bar.get_x() + bar.get_width()/2, bar.get_height()/2, label, ha='center', va='center', rotation=90)

ax[1].set_xticks([])  # Remove x-axis labels



plt.show()

# %%
dtop_cities = df1['Locality'].value_counts().head(3).index
dtop_cities_p = df2['Locality'].value_counts().head(3).index

# %%
dtop_cities_df = df[df['Locality'].isin(dtop_cities)]
dtop_cities_p_df = df[df['Locality'].isin(dtop_cities_p)]

# %%
dtop_cities_df
# Out:
#        Unnamed: 0  Area_sq.ft   Price  Price_per_sq.ft            Locality  \
# 9               9        1822  200.00            10977    Tellapur
# 19             19        1585  140.00             8833  Bachupally
# 30             30        1585  140.00             8833  Bachupally
# 33             33        1156   68.92             5963  Bachupally
# 50             50        1076  126.00            11710     Kokapet
# ...           ...         ...     ...              ...                 ...
# 23733       23733        3040  376.00            12375    Tellapur
# 23790       23790        1476  139.00             9417    Tellapur
# 23797       23797        1660  128.00             7769  Bachupally
# 23910       23910        1476  139.00             9417    Tellapur
# 23940       23940        1884  177.00             9395    Tellapur
#
#        Booking_start        Agent_Name   Direction parking Type_BHK  \
# 9                 17  Shivani Tripathi       north      No     3BHK
# 19                 3              Asha        east     Yes     3BHK
# 30                 3              Asha  north east      No     3BHK
# 33                17       Jyoti Reddy        east     Yes     2BHK
# 50                 3  YONAH PROPERTIES        east     Yes     2BHK
# ...              ...               ...         ...     ...      ...
# 23733             17       Hina Sekhar       north     Yes     3BHK
# 23790              8          SR Reddy  north east     Yes     3BHK
# 23797             17        Anjana Rao        east     Yes     3BHK
# 23910              8          SR Reddy        east      No     3BHK
# 23940              8          SR Reddy        east     Yes     3BHK
#
#       Type_Of_House
# 9         Apartment
# 19        Apartment
# 30        Apartment
# 33        Apartment
# 50        Apartment
# ...             ...
# 23733         Villa
# 23790     Apartment
# 23797     Apartment
# 23910     Apartment
# 23940     Apartment
#
# [1218 rows x 11 columns]

# %%
sns.lineplot(data=dtop_cities_df, x='Locality', y='Price', hue='Type_BHK', marker='o')
# Out:
# <AxesSubplot:xlabel='Locality', ylabel='Price'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset (replace with actual file path)
df = pd.read_csv("clean_ready_to_plot.csv")

# Create a grouped bar plot
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="Type_BHK", hue="Direction", palette="viridis")

# Labels and title
plt.xlabel("BHK Type")
plt.ylabel("Count")
plt.title("Count of BHK Types Based on Direction")
plt.legend(title="Direction")
plt.xticks(rotation=45)
plt.show()
